# %%
import pandas as pd
import numpy as np
import os

# %%
raw_data_path=os.path.join(os.path.pardir,'data','raw')
train_file_path=os.path.join(raw_data_path,'train.csv')
test_file_path=os.path.join(raw_data_path,'test.csv')

# %%
#read the data with all default params
train_df=pd.read_csv(train_file_path,index_col='PassengerId')
test_df=pd.read_csv(test_file_path,index_col='PassengerId')

# %%
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# use .info() to get brief info about the data frame
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
# Pclass      418 non-null int64
# Name        418 non-null object
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null object
# Fare        417 non-null float64
# Cabin       91 non-null object
# Embarked    418 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
test_df['Survived']=-888 # Adding Survived with a default value

# %%
df=pd.concat((train_df,test_df),axis=0) #Concatinating both data frames, 0 for row, 1 for col
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket
# PassengerId
# 1              male      1         0         A/5 21171
# 2            female      1         1          PC 17599
# ...

# %%
df.head(10) # for returning top n rows, 5 by defualt
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
# ...

# %%
df.tail()
# Out:
#               Age Cabin Embarked      Fare                          Name  \
# PassengerId
# 1305          NaN   NaN        S    8.0500            Spector, Mr. Woolf
# 1306         39.0  C105        C  108.9000  Oliva y Ocana, Dona. Fermina
# 1307         38.5   NaN        S    7.2500  Saether, Mr. Simon Sivertsen
# 1308          NaN   NaN        S    8.0500           Ware, Mr. Frederick
# 1309          NaN   NaN        C   22.3583      Peter, Master. Michael J
#
#              Parch  Pclass     Sex  SibSp  Survived              Ticket
# PassengerId
# 1305             0       3    male      0      -888           A.5. 3236
# 1306             0       1  female      0      -888            PC 17758
# 1307             0       3    male      0      -888  SOTON/O.Q. 3101262
# 1308             0       3    male      0      -888              359309
# 1309             1       3    male      1      -888                2668

# %%
df.Name
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss. Laina
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                Allen, Mr. William Henry
# 6                                        Moran, Mr. James
# 7                                 McCarthy, Mr. Timothy J
# 8                          Palsson, Master. Gosta Leonard
# 9       Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                        Sandstrom, Miss. Marguerite Rut
# 12                               Bonnell, Miss. Elizabeth
# 13                         Saundercock, Mr. William Henry
# 14                            Andersson, Mr. Anders Johan
# 15                   Vestrom, Miss. Hulda Amanda Adolfina
# 16                       Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
df['Name']
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss. Laina
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                Allen, Mr. William Henry
# 6                                        Moran, Mr. James
# 7                                 McCarthy, Mr. Timothy J
# 8                          Palsson, Master. Gosta Leonard
# 9       Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                        Sandstrom, Miss. Marguerite Rut
# 12                               Bonnell, Miss. Elizabeth
# 13                         Saundercock, Mr. William Henry
# 14                            Andersson, Mr. Anders Johan
# 15                   Vestrom, Miss. Hulda Amanda Adolfina
# 16                       Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
df[['Name','Age']]
# Out:
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# 6                                             Moran, Mr. James   NaN
# 7                                      McCarthy, Mr. Timothy J  54.0
# 8                               Palsson, Master. Gosta Leonard   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 11                             Sandstrom, Miss. Marguerite Rut   4.0
# 12                                    Bonnell, Miss. Elizabeth  58.0
# ...

# %%
df.loc[5:10,] # indexing: use loc for label based indexing,all columns
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 5                                     Allen, Mr. William Henry      0       3
# 6                                             Moran, Mr. James      0       3
# 7                                      McCarthy, Mr. Timothy J      0       1
# 8                               Palsson, Master. Gosta Leonard      1       3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2       3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      0       2
#
#                 Sex  SibSp  Survived  Ticket
# PassengerId
# ...

# %%
df.loc[5:10,"Age":"Pclass"]
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name  Parch  Pclass
# PassengerId
# 5                                     Allen, Mr. William Henry      0       3
# 6                                             Moran, Mr. James      0       3
# 7                                      McCarthy, Mr. Timothy J      0       1
# 8                               Palsson, Master. Gosta Leonard      1       3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2       3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      0       2

# %%
df.loc[5:10,['Survived','Fare',"Embarked"]]
# Out:
#              Survived     Fare Embarked
# PassengerId
# 5                   0   8.0500        S
# 6                   0   8.4583        Q
# 7                   0  51.8625        S
# 8                   0  21.0750        S
# 9                   1  11.1333        S
# 10                  1  30.0708        C

# %%
#indexing: use iloc for position based indexing
df.iloc[5:10,3:8]
# Out:
#                 Fare                                               Name  \
# PassengerId
# 6             8.4583                                   Moran, Mr. James
# 7            51.8625                            McCarthy, Mr. Timothy J
# 8            21.0750                     Palsson, Master. Gosta Leonard
# 9            11.1333  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10           30.0708                Nasser, Mrs. Nicholas (Adele Achem)
#
#              Parch  Pclass     Sex
# PassengerId
# 6                0       3    male
# 7                0       1    male
# 8                1       3    male
# 9                2       3  female
# 10               0       2  female

# %%
#filetr rows based on the condition
male_passengers=df.loc[df.Sex == 'male',:]
print('Number of male passengers : {0}'.format(len(male_passengers)))
# Out:
# Number of male passengers : 843

# %%
type(male_passengers)
# Out:
# pandas.core.frame.DataFrame

# %%
print(male_passengers)
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 1            22.0          NaN        S    7.2500
# 5            35.0          NaN        S    8.0500
# 6             NaN          NaN        Q    8.4583
# 7            54.0          E46        S   51.8625
# 8             2.0          NaN        S   21.0750
# 13           20.0          NaN        S    8.0500
# 14           39.0          NaN        S   31.2750
# 17            2.0          NaN        Q   29.1250
# 18            NaN          NaN        S   13.0000
# 21           35.0          NaN        S   26.0000
# 22           34.0          D56        S   13.0000
# 24           28.0           A6        S   35.5000
# 27            NaN          NaN        C    7.2250
# 28           19.0  C23 C25 C27        S  263.0000
# 30            NaN          NaN        S    7.8958
# 31           40.0          NaN        C   27.7208
# 34           66.0          NaN        S   10.5000
# ...

# %%
male_passengers
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 1            22.0          NaN        S    7.2500
# 5            35.0          NaN        S    8.0500
# 6             NaN          NaN        Q    8.4583
# 7            54.0          E46        S   51.8625
# 8             2.0          NaN        S   21.0750
# 13           20.0          NaN        S    8.0500
# 14           39.0          NaN        S   31.2750
# 17            2.0          NaN        Q   29.1250
# 18            NaN          NaN        S   13.0000
# 21           35.0          NaN        S   26.0000
# 22           34.0          D56        S   13.0000
# 24           28.0           A6        S   35.5000
# 27            NaN          NaN        C    7.2250
# 28           19.0  C23 C25 C27        S  263.0000
# 30            NaN          NaN        S    7.8958
# 31           40.0          NaN        C   27.7208
# 34           66.0          NaN        S   10.5000
# ...

# %%
# use & or | operators to build complex logic
male_passengers_first_class=df.loc[(df.Sex=='male')&(df.Pclass==1),:]
print('Number of male passengers in first class: {0}'.format(len(male_passengers_first_class)))
male_passengers_first_class
# Out:
# Number of male passengers in first class: 179
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 7            54.0          E46        S   51.8625
# 24           28.0           A6        S   35.5000
# 28           19.0  C23 C25 C27        S  263.0000
# 31           40.0          NaN        C   27.7208
# 35           28.0          NaN        C   82.1708
# 36           42.0          NaN        S   52.0000
# 55           65.0          B30        C   61.9792
# 56            NaN          C52        S   35.5000
# 63           45.0          C83        S   83.4750
# 65            NaN          NaN        C   27.7208
# 84           28.0          NaN        S   47.1000
# 93           46.0          E31        S   61.1750
# 97           71.0           A5        C   34.6542
# 98           23.0      D10 D12        C   63.3583
# 103          21.0          D26        S   77.2875
# 111          47.0         C110        S   52.0000
# ...

# %%
df.describe() #provide summary statistics
# Out:
#                Age         Fare        Parch       Pclass        SibSp  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027     2.294882     0.498854
# std      14.413493    51.758668     0.865560     0.837836     1.041658
# min       0.170000     0.000000     0.000000     1.000000     0.000000
# 25%      21.000000     7.895800     0.000000     2.000000     0.000000
# 50%      28.000000    14.454200     0.000000     3.000000     0.000000
# 75%      39.000000    31.275000     0.000000     3.000000     1.000000
# max      80.000000   512.329200     9.000000     3.000000     8.000000
#
#           Survived
# count  1309.000000
# mean   -283.301757
# std     414.337413
# min    -888.000000
# 25%    -888.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
print('Mean fare:{0}'.format(df.Fare.mean()))
print('Median fare:{0}'.format(df.Fare.median()))
# Out:
# Mean fare:33.2954792813
# Median fare:14.4542

# %%
print('Min fare:{0}'.format(df.Fare.min()))
print('Max fare:{0}'.format(df.Fare.max()))
print('Range fare:{0}'.format(df.Fare.max() - df.Fare.min()))
print('1st Quartile fare:{0}'.format(df.Fare.quantile(.25)))
print('2nd Quartile fare:{0}'.format(df.Fare.quantile(.5)))
print('3rd Quartile fare:{0}'.format(df.Fare.quantile(.75)))
print('Variance fare:{0}'.format(df.Fare.var()))
print('Std fare:{0}'.format(df.Fare.std()))
# Out:
# Min fare:0.0
# Max fare:512.3292
# Range fare:512.3292
# 1st Quartile fare:7.8958
# 2nd Quartile fare:14.4542
# 3rd Quartile fare:31.275
# Variance fare:2678.95973789
# Std fare:51.7586682392

# %%
# %matplotlib inline

# %%
df.Fare.plot(kind='box') #box-whisker-plot

# %%
df.describe(include="all")
# Out:
#                 Age        Cabin Embarked         Fare                  Name  \
# count   1046.000000          295     1307  1308.000000                  1309
# unique          NaN          186        3          NaN                  1307
# top             NaN  C23 C25 C27        S          NaN  Connolly, Miss. Kate
# freq            NaN            6      914          NaN                     2
# mean      29.881138          NaN      NaN    33.295479                   NaN
# std       14.413493          NaN      NaN    51.758668                   NaN
# min        0.170000          NaN      NaN     0.000000                   NaN
# 25%       21.000000          NaN      NaN     7.895800                   NaN
# 50%       28.000000          NaN      NaN    14.454200                   NaN
# 75%       39.000000          NaN      NaN    31.275000                   NaN
# max       80.000000          NaN      NaN   512.329200                   NaN
#
# ...

# %%
# categorical column: Counts
df.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts(normalize=True) # to get proportions
# Out:
# male      0.644003
# female    0.355997
# Name: Sex, dtype: float64

# %%
# apply on other columns
df[df.Survived!=-888].Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df[df.Survived!=-888].Survived.value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
df.Pclass.value_counts().plot(kind="bar")

# %%
# title: to set title,color: to set color, rot:to rotate labels
df.Pclass.value_counts().plot(kind="bar", rot=360, title="Class  wise passenger count",color="red")

# %% [markdown]
# # Distributions

# %%
# use hist to create histogram
df.Age.plot(kind="hist",title="histogram for Age", color="c")

# %%
# use bins to add or remove bins
df.Age.plot(kind="hist", title="histogram for Age", color="c", bins=20)

# %%
# use kde for density plot
df.Age.plot(kind="kde",title="Density plot for Age", color="k")

# %%
# histogram for fare
df.Fare.plot(kind="hist", title="histogram for Fare", color="c", bins=20)

# %%
print('skewness for age: {0:.2f}'.format(df.Age.skew())) # rounding to two decimal places
print('skewness for fare: {0:.2f}'.format(df.Fare.skew()))
# Out:
# skewness for age: 0.41
# skewness for fare: 4.37

# %%
# use scatter plot for bi-variate distribution
df.plot.scatter(x="Age",y="Fare",color="k",title='scatter plot : Age vs Fare')

# %%
# use alpha to set the transparency
df.plot.scatter(x="Age", y="Fare",color="k", title="scatter plot : Age vs Fare", alpha=0.5)

# %%
df.plot.scatter(x="Pclass", y="Fare", color="c",title="Scatter plot: Passenger class vs Fare", alpha=0.15)

# %% [markdown]
# # Grouping

# %%
# group by
df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      28.0
# Name: Age, dtype: float64

# %%
#group by
df.groupby(["Pclass"]).Fare.median()
# Out:
# Pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: Fare, dtype: float64

# %%
# group by
df.groupby(["Pclass"]).Age.median()
# Out:
# Pclass
# 1    39.0
# 2    29.0
# 3    24.0
# Name: Age, dtype: float64

# %%
# for multiple columns
df.groupby(['Pclass'])['Fare','Age'].median()
# Out:
#            Fare   Age
# Pclass
# 1       60.0000  39.0
# 2       15.0458  29.0
# 3        8.0500  24.0

# %%
# for extracting different summary stats for different attributes, dictionary with key(attr) val(stats) pairs
df.groupby(['Pclass']).agg({'Fare':'mean',"Age":'median'})
# Out:
#              Fare   Age
# Pclass
# 1       87.508992  39.0
# 2       21.179196  29.0
# 3       13.302889  24.0

# %%
# more complicated aggregations
aggregations={
    'Fare':{# work on the "Fare" column
        'mean_Fare':'mean',
        'median_Fare':'median',
        'max_Fare':max,
        'min_Fare':min
    },
    'Age': { # work on the "Age" column
        'median_Age':'median',
        'min_Age':min,
        'max_Age':max,
        'range_Age':lambda x: max(x)-min(x) # Calculate the age range per group
    }
}

# %%
df.groupby(['Pclass']).agg(aggregations)
# Out:
#              Fare                                    Age                       \
#         mean_Fare  max_Fare median_Fare min_Fare max_Age range_Age median_Age
# Pclass
# 1       87.508992  512.3292     60.0000      0.0    80.0     79.08       39.0
# 2       21.179196   73.5000     15.0458      0.0    70.0     69.33       29.0
# 3       13.302889   69.5500      8.0500      0.0    74.0     73.83       24.0
#
#
#        min_Age
# Pclass
# 1         0.92
# 2         0.67
# 3         0.17

# %%
df.groupby(['Pclass','Embarked']).Fare.median()
# Out:
# Pclass  Embarked
# 1       C           76.7292
#         Q           90.0000
#         S           52.0000
# 2       C           15.3146
#         Q           12.3500
#         S           15.3750
# 3       C            7.8958
#         Q            7.7500
#         S            8.0500
# Name: Fare, dtype: float64

# %% [markdown]
# # Crosstabs

# %%
# crosstab on Sex and Pclass
pd.crosstab(df.Sex, df.Pclass)
# Out:
# Pclass    1    2    3
# Sex
# female  144  106  216
# male    179  171  493

# %%
pd.crosstab(df.Sex,df.Pclass).plot(kind='bar');

# %% [markdown]
# #  Pivot Table

# %%
# pivot table
df.pivot_table(index='Sex',columns='Pclass',values='Age',aggfunc='mean')
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %%
df.groupby(['Sex','Pclass']).Age.mean()
# Out:
# Sex     Pclass
# female  1         37.037594
#         2         27.499223
#         3         22.185329
# male    1         41.029272
#         2         30.815380
#         3         25.962264
# Name: Age, dtype: float64

# %%
df.groupby(['Sex','Pclass']).Age.mean().unstack()
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264
